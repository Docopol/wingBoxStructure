# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import structure_analysis as sa
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
##Setup

bucklingForce = 3e3
positionForceX = 1.12
positionForceY = 0.175

#Whiffle tree setup 

root = sa.Node([0.75, 1.95, positionForceX, bucklingForce])

root.Insert([0.45, 1.05, 0.75, 0])
root.Insert([1.75, 2.35, 1.95, 0])
root.Insert([0.45, 0.45, 0.45, 0])
root.Insert([1.05, 1.05, 1.05, 0])
root.Insert([1.75, 1.75, 1.75, 0])
root.Insert([2.35, 2.35, 2.35, 0])

attachmentPositions = np.insert(root.PrintEndLoads(), [0], [[bucklingForce, -bucklingForce], [positionForceX, 0]], axis=1) #Adds the reaction forces and the end at index[1] and index[0] is for storing position force
attachmentPositions = np.insert(attachmentPositions, [2], np.full((1, 6), 0.025), axis=0) #This is accounts for the torsional moment but is hardcoded

#Format for elements xCg, yCg, xLength, yLength

#Bottom part stringer and then vertical part stringer
stringerGeneral = np.array([[0.01075, 0.00075, 0.0185, 0.0015], [0.00075, 0.01, 0.0015, 0.02]], dtype=np.float32)
stringerBot = np.array([[0.01075, 0.00075+0.0008, 0.0185, 0.0015], [0.00075, 0.01+0.0008, 0.0015, 0.02]], dtype=np.float32)
stringerTop = np.array([[0.01075, 0.15-0.00075-0.0008, 0.0185, 0.0015], [0.00075, 0.15-0.01-0.0008, 0.0015, 0.02]], dtype=np.float32)

#Sheet order bottom C, left A, top C, right A
sheet = np.array([[0.2, 0.0004, 0.4, 0.0008], [0.0004, 0.075, 0.0008, 0.1484], [0.2, 0.1496, 0.4, 0.0008], [0.3996, 0.075, 0.0008, 0.1484]], dtype=np.float32)

#You can modify the number of stringers

nbStringersTop = 6
nbStringersBot = 3

#Do not modify these

stringerAssemblyTop = np.repeat(stringerTop, [nbStringersTop, nbStringersTop], axis=0)
stringerAssemblyBot = np.repeat(stringerBot, [nbStringersBot, nbStringersBot], axis=0)
wingAssembly = np.concatenate((sheet, stringerAssemblyBot, stringerAssemblyTop), axis=0)

wingBox = sa.Wingbox(wingAssembly, attachmentPositions)

# %%
#Vectorizing our functions

vectShearDiagram = np.vectorize(wingBox.shearDiagram)
vectMomentDiagram = np.vectorize(wingBox.momentDiagram)
vectNormalBendingStress = np.vectorize(wingBox.normalBendingStress)
vectShearStress = np.vectorize(wingBox.shearStress)

# %%
#Fancy stuff for pgf file format

#mpl.use('pgf')

import matplotlib.pyplot as plt

# Use the seborn style
plt.style.use('seaborn-colorblind')

# But with fonts from the document body
# plt.rcParams.update({
#     "font.family": "serif",  # use serif/main font for text elements
#     "text.usetex": True,     # use inline math for ticks
#     "pgf.rcfonts": False     # don't setup fonts from rc parameters
#     })

# %%
#Making things beautifull

def set_size(width_pt, fraction=1, subplots=(1, 1)):
    """Set figure dimensions to sit nicely in our document.

    Parameters
    ----------
    width_pt: float
            Document width in points
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy
    subplots: array-like, optional
            The number of rows and columns of subplots.
    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)

# %%
#Plotting data

lengthBeam = np.arange(0.0001, 2.7, 0.01)
heightBeam = np.arange(0.0001, 0.15, 0.01)

# %%
#Vizualisation not so fancy graphs

fig, axs = plt.subplots(1, 1, figsize=set_size(370))
plt.style.use('seaborn-colorblind')
plt.grid

# plt.plot(lengthBeam, vectShearDiagram(lengthBeam)) #shear force diagram
# axs.set_ylabel('Internal shear force [N]')
# axs.set_xlabel('Distance from root [m]')
# fig.savefig('Figures/InternalShear.pdf', format='pdf')

# plt.plot(lengthBeam, vectMomentDiagram(lengthBeam, 'bending')) #bending moment diagram
# axs.set_ylabel('Internal bending moment [Nm]')
# axs.set_xlabel('Distance from root [m]')
# fig.savefig('Figures/InternalMomentBending.pdf', format='pdf')

plt.plot(lengthBeam, vectMomentDiagram(lengthBeam, 'torsion')) #torsion moment diagram
axs.set_ylabel('Internal torsional moment [Nm]')
axs.set_xlabel('Distance from root [m]')
fig.savefig('Figures/InternalMomentTorsion.pdf', format='pdf')


# plt.plot(lengthBeam, vectNormalBendingStress(lengthBeam, 'x',)) #Normal bending stress at 
# plt.plot(lengthBeam, vectShearStress(lengthBeam, 0.075, 'x', 0.0008)) #Shear stress at given height along beam

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cdc8ad66d2ec> in <module>
#       1 #Vizualisation not so fancy graphs
#       2
# ----> 3 fig, axs = plt.subplots(1, 1, figsize=set_size(370))
#       4 plt.style.use('seaborn-colorblind')
#       5 plt.grid
#
# NameError: name 'set_size' is not defined

# %%
lengthBeam = np.arange(0.0001, 2.7, 0.01)
heightBeam = np.arange(0.0001, 0.15, 0.01)

#Vizualisation fancy graphs

lengthBeam, heightBeam = np.meshgrid(lengthBeam, heightBeam)
fig.colorbar(surf, shrink=0.5, aspect=5)

fig, axs = plt.subplots(subplot_kw={"projection": "3d"}, figsize=set_size(850))

# surf = axs.plot_surface(lengthBeam, heightBeam, vectNormalBendingStress(lengthBeam, 'x', heightBeam)/1e6, cmap=mpl.cm.coolwarm,
#                        linewidth=0, antialiased=False)
# axs.set_ylabel('Height [m]', fontsize=16)
# axs.set_xlabel('Distance from root [m]', fontsize=16)
# axs.set_zlabel('Bending stress [MPa]', fontsize=16)
# fig.savefig('Figures/NormalStressDistribution.png', format='png')
    
surf = axs.plot_surface(lengthBeam, heightBeam, vectShearStress(lengthBeam, heightBeam, 'x', 0.0008)/1e6, cmap=mpl.cm.coolwarm,
                      linewidth=0, antialiased=False)
axs.set_ylabel('Height [m]', fontsize=16)
axs.set_xlabel('Distance from root [m]', fontsize=16)
axs.set_zlabel('Shear stress [MPa]', fontsize=16)
fig.savefig('Figures/ShearStressDistribution.png', format='png')

#axs.zaxis.set_major_formatter(mpl.ticker.FormatStrFormatter('%'))
#axs.zaxis.set_major_locator(mpl.ticker.LinearLocator(10))

# %%
# ?round
